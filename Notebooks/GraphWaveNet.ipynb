# %%
# !ls
# Out:
# DL-Traff-Graph.zip  sample_data

# %%
# !unzip DL-Traff-Graph.zip
# Out:
# Archive:  DL-Traff-Graph.zip
#    creating: DL-Traff-Graph/
#   inflating: __MACOSX/._DL-Traff-Graph
#   inflating: DL-Traff-Graph/.DS_Store
#   inflating: __MACOSX/DL-Traff-Graph/._.DS_Store
#   inflating: DL-Traff-Graph/LICENSE
#   inflating: __MACOSX/DL-Traff-Graph/._LICENSE
#    creating: DL-Traff-Graph/workPEMSD7M/
#   inflating: __MACOSX/DL-Traff-Graph/._workPEMSD7M
#    creating: DL-Traff-Graph/PEMSBAY/
#   inflating: __MACOSX/DL-Traff-Graph/._PEMSBAY
#    creating: DL-Traff-Graph/utils/
#   inflating: __MACOSX/DL-Traff-Graph/._utils
#   inflating: DL-Traff-Graph/README_zh-CN.md
#   inflating: __MACOSX/DL-Traff-Graph/._README_zh-CN.md
#   inflating: DL-Traff-Graph/README.md
#   inflating: __MACOSX/DL-Traff-Graph/._README.md
#    creating: DL-Traff-Graph/PEMSD7M/
#   inflating: __MACOSX/DL-Traff-Graph/._PEMSD7M
#   inflating: DL-Traff-Graph/.gitattributes
#   inflating: __MACOSX/DL-Traff-Graph/._.gitattributes
#    creating: DL-Traff-Graph/METRLA/
# ...

# %%
# %cd /content/DL-Traff-Graph/workPEMSBAY
# Out:
# /content/DL-Traff-Graph/workPEMSBAY

# %%
# !ls
# Out:
# AGCRN.py	    Param_DCRNN.py		Param_TGCN.py		   pred_MTGNN.py
# ASTGCN.py	    Param_GMAN.py		pred_AGCRN.py		   pred_STGCN12.py
# DCRNN.py	    Param_GraphWaveNet.py	pred_ASTGCN.py		   pred_STGCN3.py
# GMAN_generateSE.py  Param_HistoricalAverage.py	pred_CopyLastSteps.py	   pred_STGCN6.py
# GMAN_node2vec.py    Param_LSTNet12.py		pred_DCRNN.py		   pred_STGCN_multi.py
# GMAN.py		    Param_LSTNet3.py		pred_GMAN.py		   pred_TGCN.py
# GraphWaveNet.py     Param_LSTNet6.py		pred_GraphWaveNet.py	   STGCN.py
# LSTNet.py	    Param.py			pred_HistoricalAverage.py  TGCN.py
# Metrics.py	    Param_STGCN12.py		pred_LSTNet12.py	   Utils.py
# MTGNN.py	    Param_STGCN3.py		pred_LSTNet3.py
# Param_ASTGCN.py     Param_STGCN6.py		pred_LSTNet6.py

# %%
# !nvidia-smi
# Out:
# Mon Dec 16 06:30:24 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0              48W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# ...

# %%
# !python pred_GraphWaveNet.py
# Out:
# Using device: cuda:0
# True
# 1
# data.shape (52116, 325)
# pred_PEMS-BAY_GraphWaveNet_2412160654 training started Mon Dec 16 06:54:28 2024
# TRAIN XS.shape YS,shape (41669, 1, 325, 12) (41669, 12, 325, 1)
# Model Training Started ... Mon Dec 16 06:54:29 2024
# TIMESTEP_IN, TIMESTEP_OUT 12 12
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 32, 325, 13]              64
#             Conv2d-2          [-1, 32, 325, 12]           2,080
#             Conv2d-3          [-1, 32, 325, 12]           2,080
#             Conv2d-4         [-1, 256, 325, 12]           8,448
#              nconv-5          [-1, 32, 325, 12]               0
#              nconv-6          [-1, 32, 325, 12]               0
#              nconv-7          [-1, 32, 325, 12]               0
#              nconv-8          [-1, 32, 325, 12]               0
# ...

# %%
# !python pred_GraphWaveNet.py
# Out:
# Using device: cuda:0
# True
# 1
# data.shape (52116, 325)
# pred_PEMS-BAY_GraphWaveNet_2412160821 training started Mon Dec 16 08:21:29 2024
# TRAIN XS.shape YS,shape (41669, 1, 325, 12) (41669, 12, 325, 1)
# Model Training Started ... Mon Dec 16 08:21:30 2024
# TIMESTEP_IN, TIMESTEP_OUT 12 12
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 32, 325, 13]              64
#             Conv2d-2          [-1, 32, 325, 12]           2,080
#             Conv2d-3          [-1, 32, 325, 12]           2,080
#             Conv2d-4         [-1, 256, 325, 12]           8,448
#              nconv-5          [-1, 32, 325, 12]               0
#              nconv-6          [-1, 32, 325, 12]               0
#              nconv-7          [-1, 32, 325, 12]               0
#              nconv-8          [-1, 32, 325, 12]               0
# ...

# %%
# !zip -r /content/DL-Traff-Graph/save.zip /content/DL-Traff-Graph/save
# Out:
#   adding: content/DL-Traff-Graph/save/ (stored 0%)
#   adding: content/DL-Traff-Graph/save/pred_PEMS-BAY_GraphWaveNet_2412160805/ (stored 0%)
#   adding: content/DL-Traff-Graph/save/pred_PEMS-BAY_GraphWaveNet_2412160805/Param_GraphWaveNet.py (deflated 5%)
#   adding: content/DL-Traff-Graph/save/pred_PEMS-BAY_GraphWaveNet_2412160805/pred_GraphWaveNet.py (deflated 73%)
#   adding: content/DL-Traff-Graph/save/pred_PEMS-BAY_GraphWaveNet_2412160805/GraphWaveNet.py (deflated 74%)
#   adding: content/DL-Traff-Graph/save/pred_PEMS-BAY_GraphWaveNet_2412160805/Param.py (deflated 32%)
#   adding: content/DL-Traff-Graph/save/pred_PEMS-BAY_GraphWaveNet_2412160805/GraphWaveNet_prediction_scores.txt (deflated 26%)
#   adding: content/DL-Traff-Graph/save/pred_PEMS-BAY_GraphWaveNet_2412160821/ (stored 0%)
#   adding: content/DL-Traff-Graph/save/pred_PEMS-BAY_GraphWaveNet_2412160821/Param_GraphWaveNet.py (deflated 5%)
# ...
